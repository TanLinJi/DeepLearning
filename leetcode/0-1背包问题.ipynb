# %% [markdown]
# # 01背包问题
# 背包最大承重：4
#
# | 物品编号 | 重量 | 价值 |
# | -------- | ---- | ---- |
# | 物0      | 1    | 15   |
# | 物1      | 3    | 20   |
# | 物2      | 4    | 30   |
#
# 尽可能的使背包里的物品价值最大

# %%
dp[i][j]
