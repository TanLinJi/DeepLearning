# %%
import torchvision
import torch 
from torch import nn
from torch.nn import Sequential, Conv2d, MaxPool2d, Flatten, Linear

from torch.utils.data import DataLoader

dataset = torchvision.datasets.CIFAR10("datasets", train=False, transform=torchvision.transforms.ToTensor(), download=True)

dataloader = DataLoader(dataset=dataset, batch_size=1)

class TuDui(nn.Module):
    def __init__(self):
        super(TuDui, self).__init__()
        self.model1 = Sequential(
            Conv2d(3,32,5,padding=2),
            MaxPool2d(2),
            Conv2d(32,32,5,padding=2),
            MaxPool2d(2),
            Conv2d(32,64,5,padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(1024,64),
            Linear(64,10)
        )

    def forward(self,x):
        x = self.model1(x)
        return x
    

loss = nn.CrossEntropyLoss()
tudui = TuDui()
optim = torch.optim.SGD(tudui.parameters(), lr=0.01)  # 定义一个优化器

for epoch in range(20):
    running_loss = 0.0
    for data in dataloader:
        img,target = data
        output = tudui(img)

        result_loss = loss(output,target)
        optim.zero_grad()  # 先将网络中的每个参数的梯度设置为0
        result_loss.backward() # 调用损失函数的backward进行反向传播，求出每个参数的梯度
        optim.step()        # 对每个参数进行调优
        running_loss = running_loss + result_loss
    print("loss: " , running_loss.item())
# Out:
# loss:  18800.50390625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 44
#      42 result_loss = loss(output,target)
#      43 optim.zero_grad()  # 先将网络中的每个参数的梯度设置为0
# ---> 44 result_loss.backward() # 调用损失函数的backward进行反向传播，求出每个参数的梯度
#      45 optim.step()        # 对每个参数进行调优
#      46 running_loss = running_loss + result_loss
#
# File ~/miniconda3/envs/dl/lib/python3.11/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# ...
