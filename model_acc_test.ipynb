# %%
import torch

# %%
outputs = torch.tensor([
    [0.1, 0.2],
    [0.05, 0.4]
])

# outputs.argmax(1) # 1 就是从横向看, 0 是竖着看
outputs.argmax(0)

preds = outputs.argmax(1)
targets = torch.tensor([0,1])
print((preds == targets).sum())
# Out:
# tensor(1)
